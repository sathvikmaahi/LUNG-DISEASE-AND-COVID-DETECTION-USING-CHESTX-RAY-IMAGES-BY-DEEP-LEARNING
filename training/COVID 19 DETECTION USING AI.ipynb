# %%
from tensorflow.keras.layers import Dense, Flatten, Input
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.applications.inception_v3 import InceptionV3, preprocess_input
from glob import glob
import numpy as np
import matplotlib.pyplot as plt

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %%
imageSize = [299, 299]

trainPath = r"F:\MY PROJECTS\AI BASED COVID DETECTION\Dataset\Dataset\train\COVID"

testPath = r"F:\MY PROJECTS\AI BASED COVID DETECTION\Dataset\Dataset\test\COVID"

# %%
inception = InceptionV3(input_shape=imageSize + [3], weights='imagenet',include_top=False)

# %%
# don't train existing weights
for layer in inception.layers:
    layer.trainable = False

# %%
# our layers - you can add more if you want
x = Flatten()(inception.output)

# %%
prediction = Dense(4, activation='softmax')(x)

# %%
# create a model object
model = Model(inputs=inception.input, outputs=prediction)

# %%
# view the structure of the model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
# ...

# %%
# tell the model what cost and optimization method to use
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory(r'F:\MY PROJECTS\AI BASED COVID DETECTION\Dataset\Dataset\train',
                                                 target_size = (299, 299),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(r'F:\MY PROJECTS\AI BASED COVID DETECTION\Dataset\Dataset\test',
                                            target_size = (299, 299),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 19159 images belonging to 4 classes.
# Found 2006 images belonging to 4 classes.

# %%
# fit the model
r = model.fit(
  training_set,
  validation_data=test_set,
  epochs=25,
  steps_per_epoch=len(training_set)//32,
  validation_steps=len(test_set)//32
)
# Out:
# Epoch 1/25
# 18/18 [==============================] - 96s 5s/step - loss: 12.5988 - accuracy: 0.5434 - val_loss: 15.2758 - val_accuracy: 0.5625
# Epoch 2/25
# 18/18 [==============================] - 97s 5s/step - loss: 5.6821 - accuracy: 0.6962 - val_loss: 5.1896 - val_accuracy: 0.6875
# Epoch 3/25
# 18/18 [==============================] - 89s 5s/step - loss: 3.9103 - accuracy: 0.7326 - val_loss: 1.5532 - val_accuracy: 0.8125
# Epoch 4/25
# 18/18 [==============================] - 93s 5s/step - loss: 3.0435 - accuracy: 0.7569 - val_loss: 3.8189 - val_accuracy: 0.6562
# Epoch 5/25
# 18/18 [==============================] - 117s 7s/step - loss: 3.4113 - accuracy: 0.7431 - val_loss: 4.7941 - val_accuracy: 0.7188
# Epoch 6/25
# 18/18 [==============================] - 90s 5s/step - loss: 2.7948 - accuracy: 0.7778 - val_loss: 6.0788 - val_accuracy: 0.7500
# Epoch 7/25
# ...

# %%
model.save('InceptionV3-covid.h5')

# %%
import matplotlib.pyplot as plt
import cv2
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.applications.inception_v3 import decode_predictions

# %%
img = r'F:\MY PROJECTS\AI BASED COVID DETECTION\Dataset\Dataset\train\COVID\COVID-100.png'
image = load_img(img, target_size=(299,299))
image = img_to_array(image)
image = image.reshape((1,299,299,3))

# %%
image.shape
# Out:
# (1, 299, 299, 3)

# %%
model.predict(image)
# Out:
# 1/1 [==============================] - 5s 5s/step
# array([[1., 0., 0., 0.]], dtype=float32)
